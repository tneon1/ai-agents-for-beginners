# %%
# Ensure required packages are installed in the running kernel before importing them
# (using %pip ensures the package is installed into the kernel environment)
# Add 'pexpect' to avoid ModuleNotFoundError: No module named 'pexpect'
# %pip install "pydantic>=2.0.0" python-dotenv semantic-kernel openai pexpect

import json
import os

from dotenv import load_dotenv

# pydantic may be reported as "could not be resolved" by some linters/LS if not
# installed in the editor environment; installing above for the kernel fixes runtime.
# Add a type-ignore to suppress static linter warnings in editors if needed.
from pydantic import BaseModel, ValidationError, Field  # type: ignore
from typing import List

# Add a type-ignore so static analysis in the editor won't flag the import when
# the package is installed at runtime by the magic %pip command above.
from openai import AsyncOpenAI  # type: ignore

# Import the Semantic Kernel OpenAI connector with fallbacks for different package layouts.
# Use importlib to attempt multiple candidate module paths and add type-ignore comments to
# suppress static analyzer warnings when packages are installed at runtime via %pip above.
from importlib import import_module

def _try_import_candidates(candidates, names):
	for mod_path in candidates:
		try:
			mod = import_module(mod_path)
			return tuple(getattr(mod, name) for name in names)
		except Exception:
			continue
	raise ImportError(f"Could not import {names} from any of: {candidates}")

connector_candidates = [
	"semantic_kernel.connectors.ai.open_ai",
	"semantic_kernel.connectors.ai.openai",
	"semantic_kernel.connectors.ai",
]

try:
	OpenAIChatCompletion, OpenAIChatPromptExecutionSettings = _try_import_candidates(
		connector_candidates,
		["OpenAIChatCompletion", "OpenAIChatPromptExecutionSettings"],
	)
except ImportError:
	# Provide a clearer error if imports fail at runtime (after %pip install above)
	raise

# Import agents with fallback paths to handle different package layouts across versions.
# Try the aggregated agents module first, then fall back to importing classes from submodules.
try:
	from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread  # type: ignore
except Exception:
	try:
		from semantic_kernel.agents.chat_completion_agent import ChatCompletionAgent  # type: ignore
		from semantic_kernel.agents.chat_history_agent_thread import ChatHistoryAgentThread  # type: ignore
	except Exception:
		# If these imports still fail, raise an informative error.
		raise ImportError(
			"Could not import ChatCompletionAgent and ChatHistoryAgentThread from semantic_kernel. "
			"Ensure 'semantic-kernel' is installed in the notebook kernel (use the %pip install line above)."
		)

# Import KernelArguments with fallbacks for different semantic-kernel package layouts.
try:
	KernelArguments = _try_import_candidates(
		[
			"semantic_kernel.functions",
			"semantic_kernel.kernel",
			"semantic_kernel.core",
		],
		["KernelArguments"],
	)[0]
except Exception:
	# Provide a clearer error if imports fail at runtime
	raise ImportError(
		"Could not import 'KernelArguments' from semantic_kernel. "
		"Ensure 'semantic-kernel' is installed in the notebook kernel (use the %pip install line above)."
	)
# Out:
# Requirement already satisfied: pydantic>=2.0.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (2.11.10)
# Requirement already satisfied: python-dotenv in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (1.0.1)
# Requirement already satisfied: semantic-kernel in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (1.38.0)
# Requirement already satisfied: openai in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (1.109.1)
# Requirement already satisfied: pexpect in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (4.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pydantic>=2.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pydantic>=2.0.0) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pydantic>=2.0.0) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pydantic>=2.0.0) (0.4.2)
# Requirement already satisfied: azure-ai-projects>=1.0.0b12 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (2.0.0b2)
# Requirement already satisfied: azure-ai-agents>=1.2.0b3 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.2.0b6)
# Requirement already satisfied: aiohttp~=3.8 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (3.13.2)
# Requirement already satisfied: cloudevents~=1.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.12.0)
# Requirement already satisfied: pydantic-settings~=2.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (2.12.0)
# Requirement already satisfied: defusedxml~=0.7 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (0.7.1)
# Requirement already satisfied: azure-identity>=1.13 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.25.1)
# Requirement already satisfied: numpy>=1.26.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (2.3.5)
# Requirement already satisfied: openapi_core<0.20,>=0.18 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (0.19.5)
# Requirement already satisfied: websockets<16,>=13 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (15.0.1)
# Requirement already satisfied: aiortc>=1.9.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.14.0)
# Requirement already satisfied: opentelemetry-api~=1.24 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.38.0)
# Requirement already satisfied: prance<25.4.9,>=23.6.21 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (25.4.8.0)
# Requirement already satisfied: pybars4~=0.9 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (0.9.13)
# Requirement already satisfied: jinja2~=3.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (1.16.3)
# Requirement already satisfied: protobuf in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from semantic-kernel) (5.29.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiohttp~=3.8->semantic-kernel) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiohttp~=3.8->semantic-kernel) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiohttp~=3.8->semantic-kernel) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiohttp~=3.8->semantic-kernel) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiohttp~=3.8->semantic-kernel) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiohttp~=3.8->semantic-kernel) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiohttp~=3.8->semantic-kernel) (1.22.0)
# Requirement already satisfied: idna>=2.8 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: deprecation<3.0,>=2.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from cloudevents~=1.0->semantic-kernel) (2.1.0)
# Requirement already satisfied: packaging in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from deprecation<3.0,>=2.0->cloudevents~=1.0->semantic-kernel) (25.0)
# Requirement already satisfied: certifi in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jinja2~=3.1->semantic-kernel) (3.0.3)
# Requirement already satisfied: isodate in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (4.25.1)
# Requirement already satisfied: jsonschema-path<0.4.0,>=0.3.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.3.4)
# Requirement already satisfied: more-itertools in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (10.8.0)
# Requirement already satisfied: openapi-schema-validator<0.7.0,>=0.6.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.6.3)
# Requirement already satisfied: openapi-spec-validator<0.8.0,>=0.7.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (0.7.2)
# Requirement already satisfied: parse in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (1.20.2)
# Requirement already satisfied: werkzeug<3.1.2 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi_core<0.20,>=0.18->semantic-kernel) (3.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.29.0)
# Requirement already satisfied: PyYAML>=5.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (6.0.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (0.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.32.5)
# Requirement already satisfied: rfc3339-validator in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (0.1.4)
# Requirement already satisfied: lazy-object-proxy<2.0.0,>=1.7.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic-kernel) (1.12.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from opentelemetry-api~=1.24->semantic-kernel) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic-kernel) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from opentelemetry-sdk~=1.24->semantic-kernel) (0.59b0)
# Requirement already satisfied: chardet>=5.2 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (5.2.0)
# Requirement already satisfied: ruamel.yaml>=0.18.10 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from prance<25.4.9,>=23.6.21->semantic-kernel) (0.18.16)
# Requirement already satisfied: PyMeta3>=0.5.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pybars4~=0.9->semantic-kernel) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic-kernel) (2.5.0)
# Requirement already satisfied: ptyprocess>=0.5 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from pexpect) (0.7.0)
# Requirement already satisfied: aioice<1.0.0,>=0.10.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiortc>=1.9.0->semantic-kernel) (0.10.1)
# Requirement already satisfied: av<17.0.0,>=14.0.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiortc>=1.9.0->semantic-kernel) (16.0.1)
# Requirement already satisfied: cryptography>=44.0.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiortc>=1.9.0->semantic-kernel) (46.0.3)
# Requirement already satisfied: google-crc32c>=1.1 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiortc>=1.9.0->semantic-kernel) (1.7.1)
# Requirement already satisfied: pyee>=13.0.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiortc>=1.9.0->semantic-kernel) (13.0.0)
# Requirement already satisfied: pylibsrtp>=0.10.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiortc>=1.9.0->semantic-kernel) (1.0.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aiortc>=1.9.0->semantic-kernel) (25.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel) (2.8.0)
# Requirement already satisfied: ifaddr>=0.2.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic-kernel) (0.2.0)
# Requirement already satisfied: azure-core>=1.30.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-ai-agents>=1.2.0b3->semantic-kernel) (1.36.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-ai-projects>=1.0.0b12->semantic-kernel) (12.27.1)
# Requirement already satisfied: msal>=1.30.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-identity>=1.13->semantic-kernel) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from azure-identity>=1.13->semantic-kernel) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (2.0.0)
# Requirement already satisfied: pycparser in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.9.0->semantic-kernel) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic-kernel) (2.10.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from ruamel.yaml>=0.18.10->prance<25.4.9,>=23.6.21->semantic-kernel) (0.2.15)
# Requirement already satisfied: six in /workspaces/ai-agents-for-beginners/.venv/lib/python3.13/site-packages (from rfc3339-validator->openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic-kernel) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
load_dotenv()
client = AsyncOpenAI(
    api_key=os.environ.get("GITHUB_TOKEN"), 
    base_url="https://models.inference.ai.azure.com/",
)

chat_completion_service = OpenAIChatCompletion(
    ai_model_id="gpt-4o-mini",
    async_client=client,
)

# %%
class SubTask(BaseModel):
    assigned_agent: str = Field(
        description="The specific agent assigned to handle this subtask")
    task_details: str = Field(
        description="Detailed description of what needs to be done for this subtask")


class TravelPlan(BaseModel):
    main_task: str = Field(
        description="The overall travel request from the user")
    subtasks: List[SubTask] = Field(
        description="List of subtasks broken down from the main task, each assigned to a specialized agent")

# %%
AGENT_NAME = "TravelAgent"
AGENT_INSTRUCTIONS = """You are an planner agent.
    Your job is to decide which agents to run based on the user's request.
    Below are the available agents specialised in different tasks:
    - FlightBooking: For booking flights and providing flight information
    - HotelBooking: For booking hotels and providing hotel information
    - CarRental: For booking cars and providing car rental information
    - ActivitiesBooking: For booking activities and providing activity information
    - DestinationInfo: For providing information about destinations
    - DefaultAgent: For handling general requests"""

# Create the prompt execution settings and configure the Pydantic model response format
settings = OpenAIChatPromptExecutionSettings(response_format=TravelPlan)

agent = ChatCompletionAgent(
    service=chat_completion_service,
    name=AGENT_NAME,
    instructions=AGENT_INSTRUCTIONS,
    arguments=KernelArguments(settings) 
)

# %%
from IPython.display import display, HTML


async def main():
    # Create a thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: ChatHistoryAgentThread | None = None

    # Respond to user input
    user_inputs = [
        "Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne",
    ]

    for user_input in user_inputs:
        
        # Start building HTML output
        html_output = "<div style='margin-bottom:10px'>"
        html_output += "<div style='font-weight:bold'>User:</div>"
        html_output += f"<div style='margin-left:20px'>{user_input}</div>"
        html_output += "</div>"

        # Collect the agent's response
        response = await agent.get_response(messages=user_input, thread=thread)
        thread = response.thread

        try:
            # Try to validate the response as a TravelPlan
            travel_plan = TravelPlan.model_validate(json.loads(response.message.content))

            # Display the validated model as formatted JSON
            formatted_json = travel_plan.model_dump_json(indent=4)
            html_output += "<div style='margin-bottom:20px'>"
            html_output += "<div style='font-weight:bold'>Validated Travel Plan:</div>"
            html_output += f"<pre style='margin-left:20px; padding:10px; border-radius:5px;'>{formatted_json}</pre>"
            html_output += "</div>"
        except ValidationError as e:
            # Handle validation errors
            html_output += "<div style='margin-bottom:20px; color:red;'>"
            html_output += "<div style='font-weight:bold'>Validation Error:</div>"
            html_output += f"<pre style='margin-left:20px;'>{str(e)}</pre>"
            html_output += "</div>"
            # Add this to see what the response contains for debugging
            html_output += "<div style='margin-bottom:20px;'>"
            html_output += "<div style='font-weight:bold'>Raw Response:</div>"
            html_output += f"<div style='margin-left:20px; white-space:pre-wrap'>{response.content}</div>"
            html_output += "</div>"

        html_output += "<hr>"

        # Display formatted HTML
        display(HTML(html_output))

await main()
# Out:
# <div style='margin-bottom:10px'><div style='font-weight:bold'>User:</div><div style='margin-left:20px'>Create a travel plan for a family of 4, with 2 kids, from Singapore to Melbourne</div></div><div style='margin-bottom:20px'><div style='font-weight:bold'>Validated Travel Plan:</div><pre style='margin-left:20px; padding:10px; border-radius:5px;'>{
#     "main_task": "Create a travel plan for a family of 4 (2 adults and 2 kids) traveling from Singapore to Melbourne.",
#     "subtasks": [
#         {
#             "assigned_agent": "FlightBooking",
#             "task_details": "Book round-trip flights from Singapore to Melbourne for 4 passengers: 2 adults and 2 kids."
#         },
#         {
#             "assigned_agent": "HotelBooking",
#             "task_details": "Find and book family-friendly accommodation in Melbourne for the duration of the stay."
#         },
#         {
#             "assigned_agent": "CarRental",
#             "task_details": "Arrange car rental in Melbourne suitable for a family of 4."
#         },
#         {
#             "assigned_agent": "ActivitiesBooking",
#             "task_details": "Research and book family-friendly activities and attractions in Melbourne."
#         },
#         {
#             "assigned_agent": "DestinationInfo",
#             "task_details": "Provide information on the Melbourne destination, including tips for families and must-visit places."
#         }
#     ]
# }</pre></div><hr>

# %% [markdown]
# You should see sample output similar to:
#
# ```json
# User:
# Create a travel plan for a family of 4, with 2 kids, from Singapore to Melboune
# Validated Travel Plan:
# {
#     "main_task": "Plan a family trip from Singapore to Melbourne for 4 people including 2 kids.",
#     "subtasks": [
#         {
#             "assigned_agent": "FlightBooking",
#             "task_details": "Book round-trip flights from Singapore to Melbourne for 2 adults and 2 children."
#         },
#         {
#             "assigned_agent": "HotelBooking",
#             "task_details": "Find and book a family-friendly hotel in Melbourne that accommodates 4 people."
#         },
#         {
#             "assigned_agent": "CarRental",
#             "task_details": "Arrange for a car rental in Melbourne suitable for a family of 4."
#         },
#         {
#             "assigned_agent": "ActivitiesBooking",
#             "task_details": "Plan and book family-friendly activities in Melbourne suitable for kids."
#         },
#         {
#             "assigned_agent": "DestinationInfo",
#             "task_details": "Provide information about Melbourne, including attractions, dining options, and family-oriented activities."
#         }
#     ]
# }
# ```
